# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
images = np.load('images.npy')

# %%
# Selecting the image index at 1
selected_image = images[1]

# %%
# Save the RGB values as a CSV file
height, width, channels = selected_image.shape

with open('high_res_galaxy_image_rgb.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    # Write the header row
    writer.writerow(['Row', 'Column', 'Red', 'Green', 'Blue'])
    
    # Looping through each pixel to extract its RGB values
    for row in range(height):
        for col in range(width):
            r, g, b = selected_image[row, col]
            writer.writerow([row, col, r, g, b])

# %%
# Visualizing the image
plt.imshow(selected_image)
plt.title('Galaxy Image')
plt.show()

# %%
# Visualizing pixel intensity like the Red channel intensity
blue_channel = selected_image[:, :, 2]  # Extracting the red channel

plt.imshow(blue_channel, cmap='Blues')
plt.title('Blue Channel Intensity')
plt.colorbar()
plt.show()
